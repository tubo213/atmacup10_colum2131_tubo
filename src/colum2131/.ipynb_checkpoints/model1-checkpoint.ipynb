# %%
import os
import random
import sys
from contextlib import contextmanager
from glob import glob
from time import time

import lightgbm as lgbm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from pathlib import Path
from sklearn.decomposition import NMF, PCA, TruncatedSVD
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold, StratifiedKFold
from category_encoders.target_encoder import TargetEncoder
from gensim.models import word2vec, KeyedVectors
from tqdm import tqdm
tqdm.pandas()

import xfeat

# %%
@contextmanager
def timer(logger=None, format_str='{:.3f}[s]', prefix=None, suffix=None):
    if prefix: format_str = str(prefix) + format_str
    if suffix: format_str = format_str + str(suffix)
    start = time()
    yield
    d = time() - start
    out_str = format_str.format(d)
    if logger:
        logger.info(out_str)
    else:
        print(out_str)

def fit_lgbm_regressor(X, y, params: dict=None, verbose=100, seed: int=42):
    models = []
    oof_pred = np.zeros_like(y, dtype=np.float)
    
    bins = [1 if i > 0 else 0 for i in train_y.tolist()]
    kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
    for i, (idx_train, idx_valid) in enumerate(kf.split(X, bins)): 
        x_train, y_train = X.iloc[idx_train], y.iloc[idx_train]
        x_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid]

        model = lgbm.LGBMRegressor(**params)
        with timer(prefix='fit fold={} '.format(i + 1)):
            model.fit(x_train, y_train, 
                eval_set=[(x_valid, y_valid)],  
                early_stopping_rounds=verbose, 
                eval_metric='rmse',
                verbose=verbose)

        pred_i = model.predict(x_valid)
        oof_pred[x_valid.index] = pred_i
        models.append(model)
        print(f'Fold {i} RMSE: {np.sqrt(mean_squared_error(y_valid, pred_i)):.4f}')

    score = np.sqrt(mean_squared_error(y, oof_pred))
    print('FINISHED \ whole score: {:.4f}'.format(score))

    return oof_pred, models

def fit_lgbm_classifier(X, y, params: dict=None, verbose=100, seed: int=42):
    models = []
    oof_pred = np.zeros_like(y, dtype=np.float)
    
    bins = [1 if i > 0 else 0 for i in train_y.tolist()]
    kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
    for i, (idx_train, idx_valid) in enumerate(kf.split(X, bins)): 
        x_train, y_train = X.iloc[idx_train], y.iloc[idx_train]
        x_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid]

        model = lgbm.LGBMClassifier(**params)
        with timer(prefix='fit fold={} '.format(i + 1)):
            model.fit(x_train, y_train, 
                eval_set=[(x_valid, y_valid)],  
                early_stopping_rounds=verbose, 
                eval_metric='logloss',
                verbose=verbose)

        pred_i = model.predict_proba(x_valid)[:,1]
        oof_pred[x_valid.index] = pred_i
        models.append(model)
        print(f'Fold {i} logloss: {np.sqrt(mean_squared_error(y_valid, pred_i)):.4f}')

    score = np.sqrt(mean_squared_error(y, oof_pred))
    print('FINISHED \ whole score: {:.4f}'.format(score))

    return oof_pred, models

def create_predict_lgbm_regressor(models, feat_df):
    pred = np.array([model.predict(feat_df.values) for model in models])
    pred = np.mean(pred, axis=0)

    return pred

def create_predict_lgbm_classifier(models, feat_df):
    pred = np.array([model.predict_proba(feat_df.values)[:,1] for model in models])
    pred = np.mean(pred, axis=0)

    return pred

def run_lgbm_regressor(train_X: pd.DataFrame, train_y: pd.Series, test: pd.DataFrame, params: dict, verbose: int=50, seed: int=42):
    oof_pred, models = fit_lgbm_regressor(train_X, train_y, params=params, verbose=verbose, seed=seed)
    prediction = create_predict_lgbm_regressor(models, test)
    cv = np.sqrt(mean_squared_error(train_y, oof_pred))
    return oof_pred, prediction, models, cv

def run_lgbm_classifier(train_X: pd.DataFrame, train_y: pd.Series, test: pd.DataFrame, params: dict, verbose: int=50, seed: int=42):
    oof_pred, models = fit_lgbm_classifier(train_X, train_y, params=params, verbose=verbose, seed=seed)
    prediction = create_predict_lgbm_classifier(models, test)
    cv = np.sqrt(mean_squared_error(train_y, oof_pred))
    return oof_pred, prediction, models, cv

def visualize_importance(models, feat_train_df):
    feature_importance_df = pd.DataFrame()
    for i, model in enumerate(models):
        _df = pd.DataFrame()
        _df['feature_importance'] = model.feature_importances_
        _df['column'] = feat_train_df.columns
        _df['fold'] = i + 1
        feature_importance_df = pd.concat([feature_importance_df, _df], axis=0, ignore_index=True)

    order = feature_importance_df.groupby('column')\
        .sum()[['feature_importance']]\
        .sort_values('feature_importance', ascending=False).index[:50]

    fig, ax = plt.subplots(figsize=(max(6, len(order) * .4), 7))
    sns.boxenplot(data=feature_importance_df, x='column', y='feature_importance', order=order, ax=ax, palette='viridis')
    ax.tick_params(axis='x', rotation=90)
    ax.grid()
    fig.tight_layout()

    return feature_importance_df

# %%
data_dir = Path('../../data')
train = pd.read_csv(data_dir.joinpath('train.csv'))
test = pd.read_csv(data_dir.joinpath('test.csv'))
sub = pd.read_csv(data_dir.joinpath('atmacup10__sample_submission.csv'))

color_df = pd.read_csv(data_dir.joinpath('color.csv'))
historical_person_df = pd.read_csv(data_dir.joinpath('historical_person.csv'))
maker_df = pd.read_csv(data_dir.joinpath('maker.csv'))
material_df = pd.read_csv(data_dir.joinpath('material.csv'))
object_collection_df = pd.read_csv(data_dir.joinpath('object_collection.csv'))
palette_df = pd.read_csv(data_dir.joinpath('palette.csv'))
principal_maker_df = pd.read_csv(data_dir.joinpath('principal_maker.csv'))
principal_maker_occupatio_df = pd.read_csv(data_dir.joinpath('principal_maker_occupation.csv'))
production_place_df = pd.read_csv(data_dir.joinpath('production_place.csv'))
technique_df = pd.read_csv(data_dir.joinpath('technique.csv'))

# %%
def get_subtitle(df: pd.DataFrame):
    for axis in ['h', 'w', 't', 'd']:
        column_name = f'size_{axis}'
        size_info = df['sub_title'].str.extract(r'{} (\d*|\d*\.\d*)(cm|mm)'.format(axis)) # 正規表現を使ってサイズを抽出
        size_info = size_info.rename(columns={0: column_name, 1: 'unit'})
        size_info[column_name] = size_info[column_name].replace('', np.nan).astype(float) # dtypeがobjectになってるのでfloatに直す
        size_info[column_name] = size_info.apply(lambda row: row[column_name] * 10 if row['unit'] == 'cm' else row[column_name], axis=1) # 　単位をmmに統一する
        df[column_name] = size_info[column_name]
    
    df['size_hw'] = df['size_h'] * df['size_w']
    df['size_hwd'] = df['size_h'] * df['size_w'] * df['size_d']
    
    
    return df

train = get_subtitle(train)
test = get_subtitle(test)

material_df['count'] = material_df['name'].map(material_df['name'].value_counts())
_df = material_df.sort_values(
    ['object_id', 'count'], ascending=True
    ).groupby('object_id').first().rename(columns={'name': 'material_cat'})
train = train.merge(_df[['material_cat']], on='object_id', how='left')
test = test.merge(_df[['material_cat']], on='object_id', how='left')

# %%
def proceccing_size(train: pd.DataFrame, test:pd.DataFrame):
    df = pd.concat([train, test]).reset_index(drop=True)
    aggregated_df, aggregated_cols = xfeat.aggregation(
        df,
        group_key='principal_maker',
        group_values=['size_w', 'size_h', 'size_t', 'size_d', 'size_hw', 'size_hwd'],
        agg_methods=['mean', 'min', 'max', 'std'],
        )

    aggregated_df = aggregated_df[aggregated_cols].copy()
    for col in ['size_w', 'size_h', 'size_t', 'size_d', 'size_hw', 'size_hwd']:
        aggregated_df[f'diff_agg_mean_{col}_grpby_principal_maker'] = aggregated_df[f'agg_mean_{col}_grpby_principal_maker'] - train[col]
 
    return aggregated_df[:len(train)], aggregated_df[len(train):].reset_index(drop=True)

feature_list = [
    'artseriesid_count_basefeature',
    'title_tfidf',
    'title_basefeature',
    'title_label_basefeature',
    'title_count_basefeature',
    'description_tfidf',
    'description_basefeature',
    'description_label_basefeature',
    'description_count_basefeature',
    'longtitle_tfidf',
    'longtitle_basefeature',
    'longtitle_label_basefeature',
    'longtitle_count_basefeature',
    'principalmaker_label_basefeature',
    'principalmaker_count_basefeature',
    'principalorfirstmaker_label_basefeature',
    'principalorfirstmaker_count_basefeature',
    'subtitle_basefeature',
    'copyrightholder_label_basefeature',
    'copyrightholder_count_basefeature',
    'moretitle_tfidf',
    'moretitle_basefeature',
    'moretitle_label_basefeature',
    'moretitle_count_basefeature',
    'acquisitionmethod_label_basefeature',
    'acquisitionmethod_count_basefeature',
    'acquisitiondate_basefeature',
    'acquisitioncreditline_label_basefeature',
    'acquisitioncreditline_count_basefeature',
    'datingdate_basefeature',
    'material_basefeature',
    'object_collection_basefeature',
    'historicalperson_basefeature',
    'productionplace_basefeature',
    'technique_basefeature',
    'placeofbirth_label_basefeature',
    'placeofbirth_count_basefeature',
    'placeofdeath_label_basefeature',
    'placeofdeath_count_basefeature',
    'datebirthdeath_basefeature',
    'makername_basefeature',
    'qualification_basefeature',
    'roles_basefeature',
    'production_placesfeature',
    'color2vec_dimension_deletionfeature',
    'bert_dimension_deletionfeature',
    'targetencoding_materialfeature',
    'targetencoding_objectcollectionfeature',
    'targetencoding_techniquefeature',
    'targetencoding_dating_periodfeature'
]


features_dir = Path('../../features/colum2131/model1')

train_features = []
test_features = []

for col in ['title', 'long_title', 'more_title', 'description', 'acquisition_credit_line']:
    train_tmp = pd.read_pickle(f'../features/Universal_feature/train/{col}.pickle')
    test_tmp = pd.read_pickle(f'../features/Universal_feature/test/{col}.pickle')
    _df = pd.concat([train_tmp, test_tmp]).reset_index(drop=True)
    pca = PCA(n_components=10, random_state=42)
    features = pd.DataFrame(pca.fit_transform(_df), columns=[f'universalencoder_{col}_pca_{i}' for i in range(10)])
    
    train_features.append(features[:len(train)])
    test_features.append(features[len(train):].reset_index(drop=True)) 

for feature_name in feature_list:
    train_features.append(pd.read_feather(features_dir.joinpath(f'{feature_name}_train.ftr')))
    test_features.append(pd.read_feather(features_dir.joinpath(f'{feature_name}_test.ftr')))
    
train_X = pd.concat(train_features, axis=1)
test_X = pd.concat(test_features, axis=1)
train_y = np.log1p(train['likes'])

# %%
ensumble_dir = Path('../../ensemble/colum2131_data')

params = {
 'subsample': 1.0,
 'reg_alpha': 1.0,
 'reg_lambda': 1.0, 
 'metric': 'rmse',
 'min_child_samples': 20,
 'num_leaves': 31,
 'n_estimators': 100000,
 'objective': 'regression',
 'learning_rate': 0.01,
 'random_state': 42
 }

oof_lgbm = np.zeros(train_X.shape[0])
prediction_lgbm = np.zeros(test_X.shape[0])

SEEDS = [12] # np.arange(0, 10, 1)
for seed in SEEDS:
    params['random_state'] = seed
    oof_pred, prediction, models_lgbm, cv = run_lgbm_regressor(
        train_X=train_X,
        train_y=train_y,
        test=test_X,
        params=params,
        verbose=100,
        seed=seed)
    print(cv)

    oof_lgbm += oof_pred / len(SEEDS)
    prediction_lgbm += prediction / len(SEEDS)

cv = np.sqrt(mean_squared_error(train_y, np.where(oof_lgbm < 0, 0, oof_lgbm)))
print(f'score:{cv}')

pd.DataFrame(oof_lgbm, train.index, columns=['pred_lgbm']).to_csv(ensumble_dir / f'lgbm_train_model1.csv', index=False)
pd.DataFrame(prediction_lgbm, test.index, columns=['pred_lgbm']).to_csv(ensumble_dir / f'lgbm_tr_model1.csv', index=False)

# 0.9931 0.986201
# Out:
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 1.18941
# [200]	valid_0's rmse: 1.06394
# [300]	valid_0's rmse: 1.0278
# [400]	valid_0's rmse: 1.01453
# [500]	valid_0's rmse: 1.00649
# [600]	valid_0's rmse: 0.999414
# [700]	valid_0's rmse: 0.995086
# [800]	valid_0's rmse: 0.991803
# [900]	valid_0's rmse: 0.988997
# [1000]	valid_0's rmse: 0.98789
# [1100]	valid_0's rmse: 0.986575
# [1200]	valid_0's rmse: 0.985431
# [1300]	valid_0's rmse: 0.984923
# [1400]	valid_0's rmse: 0.984224
# [1500]	valid_0's rmse: 0.984052
# [1600]	valid_0's rmse: 0.983435
# [1700]	valid_0's rmse: 0.983088
# [1800]	valid_0's rmse: 0.982743
# [1900]	valid_0's rmse: 0.981848
# [2000]	valid_0's rmse: 0.981408
# [2100]	valid_0's rmse: 0.981231
# [2200]	valid_0's rmse: 0.980895
# [2300]	valid_0's rmse: 0.980344
# [2400]	valid_0's rmse: 0.980393
# Early stopping, best iteration is:
# [2339]	valid_0's rmse: 0.980217
# fit fold=1 26.122[s]
# Fold 0 RMSE: 0.9802
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 1.24095
# [200]	valid_0's rmse: 1.11804
# [300]	valid_0's rmse: 1.08002
# [400]	valid_0's rmse: 1.06182
# [500]	valid_0's rmse: 1.04945
# [600]	valid_0's rmse: 1.04039
# [700]	valid_0's rmse: 1.03389
# [800]	valid_0's rmse: 1.02954
# [900]	valid_0's rmse: 1.0261
# [1000]	valid_0's rmse: 1.02387
# [1100]	valid_0's rmse: 1.02194
# [1200]	valid_0's rmse: 1.02014
# [1300]	valid_0's rmse: 1.01887
# [1400]	valid_0's rmse: 1.01734
# [1500]	valid_0's rmse: 1.01642
# [1600]	valid_0's rmse: 1.01521
# [1700]	valid_0's rmse: 1.01445
# [1800]	valid_0's rmse: 1.01364
# [1900]	valid_0's rmse: 1.01288
# [2000]	valid_0's rmse: 1.01239
# [2100]	valid_0's rmse: 1.01171
# [2200]	valid_0's rmse: 1.011
# [2300]	valid_0's rmse: 1.01034
# [2400]	valid_0's rmse: 1.00943
# [2500]	valid_0's rmse: 1.00847
# [2600]	valid_0's rmse: 1.00789
# [2700]	valid_0's rmse: 1.00731
# [2800]	valid_0's rmse: 1.0067
# [2900]	valid_0's rmse: 1.00604
# [3000]	valid_0's rmse: 1.0055
# [3100]	valid_0's rmse: 1.00491
# [3200]	valid_0's rmse: 1.00481
# [3300]	valid_0's rmse: 1.0045
# [3400]	valid_0's rmse: 1.00439
# [3500]	valid_0's rmse: 1.00422
# [3600]	valid_0's rmse: 1.00406
# [3700]	valid_0's rmse: 1.00399
# [3800]	valid_0's rmse: 1.00378
# [3900]	valid_0's rmse: 1.0036
# [4000]	valid_0's rmse: 1.00357
# [4100]	valid_0's rmse: 1.00362
# [4200]	valid_0's rmse: 1.00337
# [4300]	valid_0's rmse: 1.00322
# [4400]	valid_0's rmse: 1.0031
# [4500]	valid_0's rmse: 1.0032
# Early stopping, best iteration is:
# [4465]	valid_0's rmse: 1.00302
# fit fold=2 50.401[s]
# Fold 1 RMSE: 1.0030
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 1.187
# [200]	valid_0's rmse: 1.0653
# [300]	valid_0's rmse: 1.03219
# [400]	valid_0's rmse: 1.02001
# [500]	valid_0's rmse: 1.0101
# [600]	valid_0's rmse: 1.00414
# [700]	valid_0's rmse: 0.999944
# [800]	valid_0's rmse: 0.99692
# [900]	valid_0's rmse: 0.99444
# [1000]	valid_0's rmse: 0.992153
# [1100]	valid_0's rmse: 0.990006
# [1200]	valid_0's rmse: 0.989019
# [1300]	valid_0's rmse: 0.987479
# [1400]	valid_0's rmse: 0.986477
# [1500]	valid_0's rmse: 0.985814
# [1600]	valid_0's rmse: 0.98499
# [1700]	valid_0's rmse: 0.984806
# [1800]	valid_0's rmse: 0.984389
# [1900]	valid_0's rmse: 0.983939
# [2000]	valid_0's rmse: 0.983301
# [2100]	valid_0's rmse: 0.982731
# [2200]	valid_0's rmse: 0.982656
# [2300]	valid_0's rmse: 0.982187
# [2400]	valid_0's rmse: 0.981734
# [2500]	valid_0's rmse: 0.981351
# [2600]	valid_0's rmse: 0.981061
# [2700]	valid_0's rmse: 0.980858
# [2800]	valid_0's rmse: 0.980662
# [2900]	valid_0's rmse: 0.980593
# [3000]	valid_0's rmse: 0.980254
# [3100]	valid_0's rmse: 0.980037
# [3200]	valid_0's rmse: 0.979812
# [3300]	valid_0's rmse: 0.979706
# Early stopping, best iteration is:
# [3243]	valid_0's rmse: 0.979617
# fit fold=3 40.032[s]
# Fold 2 RMSE: 0.9796
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 1.23798
# [200]	valid_0's rmse: 1.10826
# [300]	valid_0's rmse: 1.06503
# [400]	valid_0's rmse: 1.04707
# [500]	valid_0's rmse: 1.03449
# [600]	valid_0's rmse: 1.02665
# [700]	valid_0's rmse: 1.02244
# [800]	valid_0's rmse: 1.01918
# [900]	valid_0's rmse: 1.01615
# [1000]	valid_0's rmse: 1.0137
# [1100]	valid_0's rmse: 1.01191
# [1200]	valid_0's rmse: 1.01012
# [1300]	valid_0's rmse: 1.00897
# [1400]	valid_0's rmse: 1.0076
# [1500]	valid_0's rmse: 1.00635
# [1600]	valid_0's rmse: 1.00554
# [1700]	valid_0's rmse: 1.00449
# [1800]	valid_0's rmse: 1.00355
# [1900]	valid_0's rmse: 1.00272
# [2000]	valid_0's rmse: 1.00181
# [2100]	valid_0's rmse: 1.00153
# [2200]	valid_0's rmse: 1.00139
# [2300]	valid_0's rmse: 1.00135
# [2400]	valid_0's rmse: 1.00128
# [2500]	valid_0's rmse: 1.00074
# [2600]	valid_0's rmse: 1.00068
# [2700]	valid_0's rmse: 1.00055
# [2800]	valid_0's rmse: 1.00041
# [2900]	valid_0's rmse: 1.00008
# [3000]	valid_0's rmse: 0.999855
# [3100]	valid_0's rmse: 0.999531
# [3200]	valid_0's rmse: 0.999468
# [3300]	valid_0's rmse: 0.999024
# [3400]	valid_0's rmse: 0.998884
# [3500]	valid_0's rmse: 0.998691
# [3600]	valid_0's rmse: 0.99879
# Early stopping, best iteration is:
# [3550]	valid_0's rmse: 0.998652
# fit fold=4 39.633[s]
# Fold 3 RMSE: 0.9987
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 1.24463
# [200]	valid_0's rmse: 1.10796
# [300]	valid_0's rmse: 1.06781
# [400]	valid_0's rmse: 1.05052
# [500]	valid_0's rmse: 1.03972
# [600]	valid_0's rmse: 1.03201
# [700]	valid_0's rmse: 1.02667
# [800]	valid_0's rmse: 1.02244
# [900]	valid_0's rmse: 1.01872
# [1000]	valid_0's rmse: 1.01571
# [1100]	valid_0's rmse: 1.01337
# [1200]	valid_0's rmse: 1.01165
# [1300]	valid_0's rmse: 1.01004
# [1400]	valid_0's rmse: 1.00867
# [1500]	valid_0's rmse: 1.00762
# [1600]	valid_0's rmse: 1.00638
# [1700]	valid_0's rmse: 1.00594
# [1800]	valid_0's rmse: 1.00555
# [1900]	valid_0's rmse: 1.00516
# [2000]	valid_0's rmse: 1.00461
# [2100]	valid_0's rmse: 1.00387
# [2200]	valid_0's rmse: 1.00339
# [2300]	valid_0's rmse: 1.00279
# [2400]	valid_0's rmse: 1.00224
# [2500]	valid_0's rmse: 1.00153
# [2600]	valid_0's rmse: 1.00122
# [2700]	valid_0's rmse: 1.00087
# [2800]	valid_0's rmse: 1.00044
# [2900]	valid_0's rmse: 1.00027
# [3000]	valid_0's rmse: 0.999876
# [3100]	valid_0's rmse: 0.999594
# [3200]	valid_0's rmse: 0.999315
# [3300]	valid_0's rmse: 0.999404
# Early stopping, best iteration is:
# [3210]	valid_0's rmse: 0.999264
# fit fold=5 39.406[s]
# Fold 4 RMSE: 0.9993
# FINISHED \ whole score: 0.9922
# 0.9922056106821708
# score:0.9920973895859858

# %%
importance = visualize_importance(models_lgbm, train_X)

# %%
cv = np.sqrt(mean_squared_error(train_y, oof_lgbm))
print(f'score:{cv}')
sub['likes'] = np.expm1(prediction_lgbm)
sub['likes'] = sub['likes'].map(lambda x: x if x > 0 else 0)
sub.to_csv(f'../outputs/cv{cv}.csv', index=False)
# Out:
# score:0.9932466388292548

# %% [markdown]
# # XGbosst

# %%
import xgboost as xgb

# XGBoost
def fit_xgb(X, y, params: dict=None, verbose=100, seed: int=42):
    models = []
    oof_pred = np.zeros_like(y, dtype=np.float)

    bins = [1 if i > 0 else 0 for i in train_y.tolist()]
    kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
    for i, (idx_train, idx_valid) in enumerate(kf.split(X, bins)): 
        x_train, y_train = X.iloc[idx_train], y.iloc[idx_train]
        x_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid]

        xgb_train = xgb.DMatrix(x_train, label=y_train)
        xgb_valid = xgb.DMatrix(x_valid, label=y_valid)
        evals = [(xgb_train,'train'),(xgb_valid,'eval')]

        model = xgb.train(
            params,
            xgb_train,
            num_boost_round=100000,
            early_stopping_rounds=verbose,
            evals=evals,
            verbose_eval=verbose)

        pred_i = model.predict(xgb.DMatrix(x_valid))
        oof_pred[x_valid.index] = pred_i
        models.append(model)
        print(f'Fold {i} RMSE: {np.sqrt(mean_squared_error(y_valid, pred_i)):.4f}')

    score = np.sqrt(mean_squared_error(y, oof_pred))
    print('FINISHED \ whole score: {:.4f}'.format(score))
    return oof_pred, models

def create_predict_xgb(models, feat_df):
    pred = np.array([model.predict(xgb.DMatrix(feat_df)) for model in models])
    pred = np.mean(pred, axis=0)
    return pred

def run_xgb(train_X: pd.DataFrame, train_y: pd.Series, test: pd.DataFrame, params: dict, verbose: int=50, seed: int=42):
    oof_pred, models = fit_xgb(train_X, train_y, params=params, verbose=verbose, seed=seed)
    prediction = create_predict_xgb(models, test)
    cv = np.sqrt(mean_squared_error(train_y, oof_pred))
    return oof_pred, prediction, models, cv

# %%
xgb_params = {
    'objective': 'reg:squarederror',
    'eval_metric':'rmse',
    'learning_rate':0.01,
    'tree_method':'gpu_hist'}

oof_xgb = np.zeros(train_X.shape[0])
prediction_xgb = np.zeros(test_X.shape[0])

SEEDS = [12] # np.arange(0, 5, 1)
for seed in SEEDS:
    oof_pred, prediction, models_xgb, cv = run_xgb(
        train_X=train_X,
        train_y=train_y,
        test=test_X,
        params=xgb_params,
        verbose=100,
        seed=seed)
    print(cv)

    oof_xgb += oof_pred / len(SEEDS)
    prediction_xgb += prediction / len(SEEDS)

cv = np.sqrt(mean_squared_error(train_y, oof_xgb))
print(f'score:{cv}')

pd.DataFrame(oof_xgb, train.index, columns=['pred_xgb']).to_csv('../data/xgb_train.csv', index=False)
pd.DataFrame(prediction_xgb, test.index, columns=['pred_xgb']).to_csv('../data/xgb_test.csv', index=False)
# Out:
# [0]	train-rmse:2.10703	eval-rmse:2.08036
# [100]	train-rmse:1.22935	eval-rmse:1.24823
# [200]	train-rmse:0.97719	eval-rmse:1.06716
# [300]	train-rmse:0.87790	eval-rmse:1.02209
# [400]	train-rmse:0.81598	eval-rmse:1.00926
# [500]	train-rmse:0.77127	eval-rmse:1.00316
# [600]	train-rmse:0.73999	eval-rmse:0.99798
# [700]	train-rmse:0.71300	eval-rmse:0.99479
# [800]	train-rmse:0.68689	eval-rmse:0.99260
# [900]	train-rmse:0.66196	eval-rmse:0.99109
# [1000]	train-rmse:0.63711	eval-rmse:0.98931
# [1100]	train-rmse:0.61485	eval-rmse:0.98780
# [1200]	train-rmse:0.59300	eval-rmse:0.98647
# [1300]	train-rmse:0.57356	eval-rmse:0.98510
# [1400]	train-rmse:0.55450	eval-rmse:0.98440
# [1500]	train-rmse:0.53733	eval-rmse:0.98411
# [1600]	train-rmse:0.52010	eval-rmse:0.98366
# [1700]	train-rmse:0.50401	eval-rmse:0.98289
# [1800]	train-rmse:0.48938	eval-rmse:0.98238
# [1900]	train-rmse:0.47541	eval-rmse:0.98184
# [2000]	train-rmse:0.46257	eval-rmse:0.98157
# [2100]	train-rmse:0.44966	eval-rmse:0.98136
# [2200]	train-rmse:0.43733	eval-rmse:0.98122
# [2300]	train-rmse:0.42461	eval-rmse:0.98093
# [2400]	train-rmse:0.41378	eval-rmse:0.98049
# [2500]	train-rmse:0.40263	eval-rmse:0.98052
# [2522]	train-rmse:0.40058	eval-rmse:0.98047
# Fold 0 RMSE: 0.9805
# [0]	train-rmse:2.09953	eval-rmse:2.11102
# [100]	train-rmse:1.21946	eval-rmse:1.31509
# [200]	train-rmse:0.96423	eval-rmse:1.13033
# [300]	train-rmse:0.86629	eval-rmse:1.08080
# [400]	train-rmse:0.80611	eval-rmse:1.06064
# [500]	train-rmse:0.76589	eval-rmse:1.05195
# [600]	train-rmse:0.73211	eval-rmse:1.04601
# [700]	train-rmse:0.70230	eval-rmse:1.04131
# [800]	train-rmse:0.67633	eval-rmse:1.03738
# [900]	train-rmse:0.65135	eval-rmse:1.03412
# [1000]	train-rmse:0.62944	eval-rmse:1.03137
# [1100]	train-rmse:0.60945	eval-rmse:1.02938
# [1200]	train-rmse:0.59149	eval-rmse:1.02768
# [1300]	train-rmse:0.57349	eval-rmse:1.02570
# [1400]	train-rmse:0.55615	eval-rmse:1.02440
# [1500]	train-rmse:0.54017	eval-rmse:1.02329
# [1600]	train-rmse:0.52505	eval-rmse:1.02227
# [1700]	train-rmse:0.50916	eval-rmse:1.02133
# [1800]	train-rmse:0.49552	eval-rmse:1.02065
# [1900]	train-rmse:0.48216	eval-rmse:1.02018
# [2000]	train-rmse:0.46900	eval-rmse:1.01984
# [2100]	train-rmse:0.45729	eval-rmse:1.01959
# [2200]	train-rmse:0.44579	eval-rmse:1.01898
# [2300]	train-rmse:0.43456	eval-rmse:1.01832
# [2400]	train-rmse:0.42311	eval-rmse:1.01782
# [2500]	train-rmse:0.41256	eval-rmse:1.01741
# [2600]	train-rmse:0.40163	eval-rmse:1.01687
# [2700]	train-rmse:0.39156	eval-rmse:1.01645
# [2800]	train-rmse:0.38153	eval-rmse:1.01607
# [2900]	train-rmse:0.37205	eval-rmse:1.01552
# [3000]	train-rmse:0.36384	eval-rmse:1.01533
# [3055]	train-rmse:0.35833	eval-rmse:1.01540
# Fold 1 RMSE: 1.0154
# [0]	train-rmse:2.11223	eval-rmse:2.05892
# [100]	train-rmse:1.23051	eval-rmse:1.24571
# [200]	train-rmse:0.97330	eval-rmse:1.06983
# [300]	train-rmse:0.87489	eval-rmse:1.03188
# [400]	train-rmse:0.81137	eval-rmse:1.01987
# [500]	train-rmse:0.76349	eval-rmse:1.01194
# [600]	train-rmse:0.73039	eval-rmse:1.00789
# [700]	train-rmse:0.70190	eval-rmse:1.00446
# [800]	train-rmse:0.67659	eval-rmse:1.00206
# [900]	train-rmse:0.65379	eval-rmse:0.99979
# [1000]	train-rmse:0.63355	eval-rmse:0.99846
# [1100]	train-rmse:0.61610	eval-rmse:0.99747
# [1200]	train-rmse:0.59885	eval-rmse:0.99628
# [1300]	train-rmse:0.58095	eval-rmse:0.99527
# [1400]	train-rmse:0.56498	eval-rmse:0.99414
# [1500]	train-rmse:0.55026	eval-rmse:0.99332
# [1600]	train-rmse:0.53497	eval-rmse:0.99222
# [1700]	train-rmse:0.52050	eval-rmse:0.99158
# [1800]	train-rmse:0.50784	eval-rmse:0.99095
# [1900]	train-rmse:0.49611	eval-rmse:0.99043
# [2000]	train-rmse:0.48376	eval-rmse:0.98994
# [2100]	train-rmse:0.47122	eval-rmse:0.98950
# [2200]	train-rmse:0.45903	eval-rmse:0.98907
# [2300]	train-rmse:0.44772	eval-rmse:0.98881
# [2400]	train-rmse:0.43570	eval-rmse:0.98828
# [2500]	train-rmse:0.42481	eval-rmse:0.98798
# [2600]	train-rmse:0.41452	eval-rmse:0.98777
# [2700]	train-rmse:0.40335	eval-rmse:0.98753
# [2800]	train-rmse:0.39348	eval-rmse:0.98756
# [2900]	train-rmse:0.38157	eval-rmse:0.98706
# [3000]	train-rmse:0.37129	eval-rmse:0.98693
# [3100]	train-rmse:0.36163	eval-rmse:0.98647
# [3200]	train-rmse:0.35211	eval-rmse:0.98625
# [3290]	train-rmse:0.34421	eval-rmse:0.98639
# Fold 2 RMSE: 0.9864
# [0]	train-rmse:2.09557	eval-rmse:2.12681
# [100]	train-rmse:1.22497	eval-rmse:1.31183
# [200]	train-rmse:0.97156	eval-rmse:1.12252
# [300]	train-rmse:0.87125	eval-rmse:1.07056
# [400]	train-rmse:0.81026	eval-rmse:1.05123
# [500]	train-rmse:0.76526	eval-rmse:1.04193
# [600]	train-rmse:0.73129	eval-rmse:1.03582
# [700]	train-rmse:0.70596	eval-rmse:1.03283
# [800]	train-rmse:0.68393	eval-rmse:1.03047
# [900]	train-rmse:0.66203	eval-rmse:1.02816
# [1000]	train-rmse:0.64065	eval-rmse:1.02579
# [1100]	train-rmse:0.61998	eval-rmse:1.02378
# [1200]	train-rmse:0.60112	eval-rmse:1.02178
# [1300]	train-rmse:0.58276	eval-rmse:1.02027
# [1400]	train-rmse:0.56626	eval-rmse:1.01886
# [1500]	train-rmse:0.54927	eval-rmse:1.01797
# [1600]	train-rmse:0.53361	eval-rmse:1.01739
# [1700]	train-rmse:0.51954	eval-rmse:1.01689
# [1800]	train-rmse:0.50649	eval-rmse:1.01645
# [1900]	train-rmse:0.49481	eval-rmse:1.01626
# [2000]	train-rmse:0.48151	eval-rmse:1.01580
# [2100]	train-rmse:0.46846	eval-rmse:1.01543
# [2200]	train-rmse:0.45448	eval-rmse:1.01481
# [2300]	train-rmse:0.44330	eval-rmse:1.01423
# [2400]	train-rmse:0.43285	eval-rmse:1.01366
# [2500]	train-rmse:0.42260	eval-rmse:1.01318
# [2600]	train-rmse:0.41241	eval-rmse:1.01255
# [2700]	train-rmse:0.40186	eval-rmse:1.01216
# [2777]	train-rmse:0.39402	eval-rmse:1.01225
# Fold 3 RMSE: 1.0122
# [0]	train-rmse:2.09405	eval-rmse:2.13295
# [100]	train-rmse:1.21875	eval-rmse:1.31389
# [200]	train-rmse:0.96349	eval-rmse:1.11802
# [300]	train-rmse:0.86578	eval-rmse:1.06779
# [400]	train-rmse:0.80641	eval-rmse:1.04958
# [500]	train-rmse:0.76224	eval-rmse:1.04132
# [600]	train-rmse:0.72716	eval-rmse:1.03584
# [700]	train-rmse:0.69983	eval-rmse:1.03196
# [800]	train-rmse:0.67380	eval-rmse:1.02862
# [900]	train-rmse:0.64883	eval-rmse:1.02576
# [1000]	train-rmse:0.62614	eval-rmse:1.02340
# [1100]	train-rmse:0.60483	eval-rmse:1.02104
# [1200]	train-rmse:0.58617	eval-rmse:1.01970
# [1300]	train-rmse:0.56889	eval-rmse:1.01887
# [1400]	train-rmse:0.55258	eval-rmse:1.01750
# [1500]	train-rmse:0.53847	eval-rmse:1.01660
# [1600]	train-rmse:0.52430	eval-rmse:1.01553
# [1700]	train-rmse:0.51037	eval-rmse:1.01462
# [1800]	train-rmse:0.49794	eval-rmse:1.01376
# [1900]	train-rmse:0.48508	eval-rmse:1.01316
# [2000]	train-rmse:0.47322	eval-rmse:1.01258
# [2100]	train-rmse:0.46170	eval-rmse:1.01209
# [2200]	train-rmse:0.45099	eval-rmse:1.01196
# [2300]	train-rmse:0.44028	eval-rmse:1.01164
# [2400]	train-rmse:0.42950	eval-rmse:1.01125
# [2500]	train-rmse:0.41964	eval-rmse:1.01080
# [2600]	train-rmse:0.41048	eval-rmse:1.01057
# [2700]	train-rmse:0.39960	eval-rmse:1.01024
# [2800]	train-rmse:0.39035	eval-rmse:1.01008
# [2900]	train-rmse:0.38091	eval-rmse:1.00987
# [3000]	train-rmse:0.37091	eval-rmse:1.00989
# [3100]	train-rmse:0.36097	eval-rmse:1.00963
# [3200]	train-rmse:0.35177	eval-rmse:1.00958
# [3293]	train-rmse:0.34335	eval-rmse:1.00989
# Fold 4 RMSE: 1.0099
# FINISHED \ whole score: 1.0010
# 1.0009796899837085
# score:1.0009796899837085

# %%
cv = np.sqrt(mean_squared_error(train_y, oof_xgb))
print(f'score:{cv}')
sub['likes'] = np.expm1(prediction_xgb)
sub['likes'] = sub['likes'].map(lambda x: x if x > 0 else 0)
sub.to_csv(f'../outputs/cv{cv}.csv', index=False)
# Out:
# score:1.0009796899837085

# %% [markdown]
# # CatBoost

# %%
# Catboost
from catboost import CatBoost, Pool

def fit_cat(X, y, params: dict=None, verbose=100, seed=42):
    models = []
    oof_pred = np.zeros_like(y, dtype=np.float)

    bins = [1 if i > 0 else 0 for i in train_y.tolist()]
    kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
    for i, (idx_train, idx_valid) in enumerate(kf.split(X, bins)): 
        x_train, y_train = X.iloc[idx_train], y.iloc[idx_train]
        x_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid]

        train_pool = Pool(
            x_train,
            label=y_train,
            cat_features=categorycal_list)
        
        valid_pool = Pool(
            x_valid,
            label=y_valid,
            cat_features=categorycal_list)
        
        model = CatBoost(params)
        model.fit(
            train_pool,
            early_stopping_rounds=verbose,
            plot=False,
            use_best_model=True,
            eval_set=[valid_pool],
            verbose=verbose)

        pred_i = model.predict(x_valid)
        oof_pred[x_valid.index] = pred_i
        models.append(model)
        print(f'Fold {i} RMSE: {np.sqrt(mean_squared_error(y_valid, pred_i)):.4f}')

    score = np.sqrt(mean_squared_error(y, oof_pred))
    print('FINISHED \ whole score: {:.4f}'.format(score))
    return oof_pred, models

def create_predict_cat(models, feat_df):
    pred = np.array([model.predict(feat_df) for model in models])
    pred = np.mean(pred, axis=0)
    return pred

def run_cat(train_X: pd.DataFrame, train_y: pd.Series, test: pd.DataFrame, params: dict, verbose: int=50, seed: int=42):
    oof_pred, models = fit_cat(train_X, train_y, params=params, verbose=verbose, seed=seed)
    prediction = create_predict_cat(models, test)
    cv = np.sqrt(mean_squared_error(train_y, oof_pred))
    return oof_pred, prediction, models, cv

# %%
categorycal_list = []
for i, col in enumerate(train_X.columns):
    if 'label' in col:
        categorycal_list.append(i)
        train_X[col] = train_X[col].astype(object)
        test_X[col] = test_X[col].astype(object)

# %%
cat_params = {
    'loss_function': 'RMSE',
    'num_boost_round': 100000,
    'learning_rate': 0.03,
    'random_state': 42,
    'task_type': 'CPU',
    }

oof_cat = np.zeros(train_X.shape[0])
prediction_cat = np.zeros(test_X.shape[0])

SEEDS = [12] # np.arange(0, 5, 1)
for seed in SEEDS:
    oof_pred, prediction, models_cat, cv = run_cat(
        train_X=train_X,
        train_y=train_y,
        test=test_X,
        params=cat_params,
        verbose=100,
        seed=seed)
    print(cv)

    oof_cat += oof_pred / len(SEEDS)
    prediction_cat += prediction / len(SEEDS)

cv = np.sqrt(mean_squared_error(train_y, oof_cat))
print(f'score:{cv}')

pd.DataFrame(oof_cat, train.index, columns=['pred_cat']).to_csv('../data/cat_train.csv', index=False)
pd.DataFrame(prediction_cat, test.index, columns=['pred_cat']).to_csv('../data/cat_test.csv', index=False)
# Out:
# 0:	learn: 1.7534154	test: 1.7190627	best: 1.7190627 (0)	total: 96.7ms	remaining: 2h 41m 11s
# 100:	learn: 1.1052018	test: 1.0766274	best: 1.0766274 (100)	total: 4.73s	remaining: 1h 18m 1s
# 200:	learn: 1.0427036	test: 1.0435142	best: 1.0435142 (200)	total: 9.22s	remaining: 1h 16m 20s
# 300:	learn: 0.9987995	test: 1.0263410	best: 1.0263410 (300)	total: 13.7s	remaining: 1h 15m 47s
# 400:	learn: 0.9537922	test: 1.0139344	best: 1.0139344 (400)	total: 18.2s	remaining: 1h 15m 24s
# 500:	learn: 0.9137712	test: 1.0073999	best: 1.0073999 (500)	total: 23s	remaining: 1h 16m 8s
# 600:	learn: 0.8807877	test: 1.0022588	best: 1.0022588 (600)	total: 27.8s	remaining: 1h 16m 30s
# 700:	learn: 0.8495401	test: 0.9989400	best: 0.9989400 (700)	total: 32.4s	remaining: 1h 16m 31s
# 800:	learn: 0.8227236	test: 0.9952922	best: 0.9952922 (800)	total: 37s	remaining: 1h 16m 18s
# 900:	learn: 0.7976367	test: 0.9937636	best: 0.9937636 (900)	total: 41.5s	remaining: 1h 16m 3s
# 1000:	learn: 0.7746607	test: 0.9920426	best: 0.9920426 (1000)	total: 46.1s	remaining: 1h 15m 57s
# 1100:	learn: 0.7519740	test: 0.9899462	best: 0.9899291 (1099)	total: 50.7s	remaining: 1h 15m 50s
# 1200:	learn: 0.7312342	test: 0.9882823	best: 0.9882556 (1198)	total: 55.2s	remaining: 1h 15m 45s
# 1300:	learn: 0.7120768	test: 0.9867552	best: 0.9867213 (1285)	total: 59.7s	remaining: 1h 15m 32s
# 1400:	learn: 0.6939497	test: 0.9858776	best: 0.9858424 (1398)	total: 1m 4s	remaining: 1h 15m 25s
# 1500:	learn: 0.6752331	test: 0.9845462	best: 0.9845462 (1500)	total: 1m 8s	remaining: 1h 15m 17s
# 1600:	learn: 0.6585091	test: 0.9838441	best: 0.9838345 (1599)	total: 1m 13s	remaining: 1h 15m 10s
# 1700:	learn: 0.6417961	test: 0.9829437	best: 0.9829437 (1700)	total: 1m 17s	remaining: 1h 15m 1s
# 1800:	learn: 0.6262193	test: 0.9829319	best: 0.9828402 (1783)	total: 1m 22s	remaining: 1h 14m 52s
# 1900:	learn: 0.6110954	test: 0.9832119	best: 0.9826123 (1862)	total: 1m 26s	remaining: 1h 14m 43s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.9826123261
# bestIteration = 1862
#
# Shrink model to first 1863 iterations.
# Fold 0 RMSE: 0.9826
# 0:	learn: 1.7444158	test: 1.7569666	best: 1.7569666 (0)	total: 45.3ms	remaining: 1h 15m 33s
# 100:	learn: 1.0902309	test: 1.1408896	best: 1.1408896 (100)	total: 4.61s	remaining: 1h 16m 1s
# 200:	learn: 1.0286343	test: 1.0995017	best: 1.0995017 (200)	total: 9.84s	remaining: 1h 21m 23s
# 300:	learn: 0.9878987	test: 1.0776059	best: 1.0776059 (300)	total: 15.1s	remaining: 1h 23m 31s
# 400:	learn: 0.9461780	test: 1.0629777	best: 1.0629777 (400)	total: 20.4s	remaining: 1h 24m 21s
# 500:	learn: 0.9078294	test: 1.0529893	best: 1.0529893 (500)	total: 24.9s	remaining: 1h 22m 32s
# 600:	learn: 0.8750162	test: 1.0456589	best: 1.0456589 (600)	total: 29.4s	remaining: 1h 21m 1s
# 700:	learn: 0.8444880	test: 1.0384687	best: 1.0384170 (697)	total: 33.9s	remaining: 1h 20m 5s
# 800:	learn: 0.8170652	test: 1.0333691	best: 1.0333691 (800)	total: 38.4s	remaining: 1h 19m 20s
# 900:	learn: 0.7914868	test: 1.0289419	best: 1.0288926 (899)	total: 42.9s	remaining: 1h 18m 42s
# 1000:	learn: 0.7677745	test: 1.0255752	best: 1.0255752 (1000)	total: 47.4s	remaining: 1h 18m 11s
# 1100:	learn: 0.7460248	test: 1.0227404	best: 1.0226814 (1091)	total: 51.9s	remaining: 1h 17m 44s
# 1200:	learn: 0.7248654	test: 1.0198328	best: 1.0198328 (1200)	total: 56.4s	remaining: 1h 17m 21s
# 1300:	learn: 0.7058185	test: 1.0180938	best: 1.0180703 (1295)	total: 1m	remaining: 1h 17m 1s
# 1400:	learn: 0.6876874	test: 1.0155273	best: 1.0154831 (1399)	total: 1m 5s	remaining: 1h 16m 42s
# 1500:	learn: 0.6702565	test: 1.0137376	best: 1.0137360 (1495)	total: 1m 9s	remaining: 1h 16m 25s
# 1600:	learn: 0.6537397	test: 1.0123777	best: 1.0123777 (1600)	total: 1m 14s	remaining: 1h 16m 31s
# 1700:	learn: 0.6371037	test: 1.0109265	best: 1.0108611 (1699)	total: 1m 19s	remaining: 1h 16m 23s
# 1800:	learn: 0.6220628	test: 1.0102190	best: 1.0101205 (1794)	total: 1m 23s	remaining: 1h 16m 11s
# 1900:	learn: 0.6074397	test: 1.0096615	best: 1.0095886 (1885)	total: 1m 28s	remaining: 1h 15m 59s
# 2000:	learn: 0.5929610	test: 1.0085424	best: 1.0083575 (1995)	total: 1m 32s	remaining: 1h 15m 48s
# 2100:	learn: 0.5787632	test: 1.0074557	best: 1.0074557 (2100)	total: 1m 37s	remaining: 1h 15m 38s
# 2200:	learn: 0.5648593	test: 1.0063847	best: 1.0063706 (2197)	total: 1m 41s	remaining: 1h 15m 28s
# 2300:	learn: 0.5524676	test: 1.0054779	best: 1.0054192 (2299)	total: 1m 46s	remaining: 1h 15m 18s
# 2400:	learn: 0.5394909	test: 1.0051968	best: 1.0051035 (2387)	total: 1m 50s	remaining: 1h 15m 8s
# 2500:	learn: 0.5273818	test: 1.0046161	best: 1.0046161 (2500)	total: 1m 55s	remaining: 1h 15m
# 2600:	learn: 0.5159295	test: 1.0044596	best: 1.0042789 (2559)	total: 1m 59s	remaining: 1h 14m 50s
# 2700:	learn: 0.5047254	test: 1.0040435	best: 1.0040183 (2697)	total: 2m 4s	remaining: 1h 14m 43s
# 2800:	learn: 0.4930385	test: 1.0033932	best: 1.0033863 (2794)	total: 2m 8s	remaining: 1h 14m 35s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.00338627
# bestIteration = 2794
#
# Shrink model to first 2795 iterations.
# Fold 1 RMSE: 1.0034
# 0:	learn: 1.7550649	test: 1.7128150	best: 1.7128150 (0)	total: 45.2ms	remaining: 1h 15m 23s
# 100:	learn: 1.1022958	test: 1.0853668	best: 1.0853668 (100)	total: 4.53s	remaining: 1h 14m 39s
# 200:	learn: 1.0403735	test: 1.0522991	best: 1.0522991 (200)	total: 9.07s	remaining: 1h 15m 1s
# 300:	learn: 0.9988241	test: 1.0359566	best: 1.0359566 (300)	total: 13.5s	remaining: 1h 14m 41s
# 400:	learn: 0.9567207	test: 1.0246694	best: 1.0246694 (400)	total: 18.2s	remaining: 1h 15m 9s
# 500:	learn: 0.9184078	test: 1.0169890	best: 1.0169890 (500)	total: 22.6s	remaining: 1h 14m 44s
# 600:	learn: 0.8863472	test: 1.0121951	best: 1.0121007 (596)	total: 27s	remaining: 1h 14m 29s
# 700:	learn: 0.8582600	test: 1.0077504	best: 1.0076643 (698)	total: 31.4s	remaining: 1h 14m 12s
# 800:	learn: 0.8336447	test: 1.0049038	best: 1.0048537 (797)	total: 35.8s	remaining: 1h 13m 58s
# 900:	learn: 0.8091033	test: 1.0012062	best: 1.0012062 (900)	total: 40.3s	remaining: 1h 13m 48s
# 1000:	learn: 0.7865452	test: 0.9985592	best: 0.9985592 (1000)	total: 44.7s	remaining: 1h 13m 40s
# 1100:	learn: 0.7656297	test: 0.9961837	best: 0.9961837 (1100)	total: 49.1s	remaining: 1h 13m 32s
# 1200:	learn: 0.7454940	test: 0.9940251	best: 0.9940251 (1200)	total: 53.5s	remaining: 1h 13m 24s
# 1300:	learn: 0.7254878	test: 0.9924372	best: 0.9924372 (1300)	total: 58.1s	remaining: 1h 13m 26s
# 1400:	learn: 0.7067496	test: 0.9904101	best: 0.9903808 (1399)	total: 1m 2s	remaining: 1h 13m 21s
# 1500:	learn: 0.6887305	test: 0.9890906	best: 0.9890451 (1488)	total: 1m 7s	remaining: 1h 13m 16s
# 1600:	learn: 0.6713592	test: 0.9874300	best: 0.9874267 (1587)	total: 1m 11s	remaining: 1h 13m 13s
# 1700:	learn: 0.6539497	test: 0.9866952	best: 0.9866446 (1699)	total: 1m 15s	remaining: 1h 13m 9s
# 1800:	learn: 0.6381187	test: 0.9860833	best: 0.9860576 (1798)	total: 1m 20s	remaining: 1h 13m 4s
# 1900:	learn: 0.6219613	test: 0.9851312	best: 0.9849929 (1891)	total: 1m 25s	remaining: 1h 13m 22s
# 2000:	learn: 0.6076036	test: 0.9845248	best: 0.9843652 (1990)	total: 1m 29s	remaining: 1h 13m 26s
# 2100:	learn: 0.5934341	test: 0.9829830	best: 0.9828978 (2098)	total: 1m 34s	remaining: 1h 13m 44s
# 2200:	learn: 0.5788725	test: 0.9828244	best: 0.9827905 (2182)	total: 1m 40s	remaining: 1h 14m 19s
# 2300:	learn: 0.5649578	test: 0.9819464	best: 0.9819464 (2300)	total: 1m 45s	remaining: 1h 14m 42s
# 2400:	learn: 0.5515928	test: 0.9814977	best: 0.9813503 (2375)	total: 1m 50s	remaining: 1h 15m 8s
# 2500:	learn: 0.5392513	test: 0.9807819	best: 0.9807592 (2499)	total: 1m 56s	remaining: 1h 15m 32s
# 2600:	learn: 0.5272105	test: 0.9806331	best: 0.9806154 (2594)	total: 2m 2s	remaining: 1h 16m 17s
# 2700:	learn: 0.5157439	test: 0.9802658	best: 0.9801759 (2689)	total: 2m 7s	remaining: 1h 16m 19s
# 2800:	learn: 0.5042221	test: 0.9798653	best: 0.9798583 (2764)	total: 2m 12s	remaining: 1h 16m 27s
# 2900:	learn: 0.4933628	test: 0.9798028	best: 0.9797942 (2866)	total: 2m 16s	remaining: 1h 16m 21s
# 3000:	learn: 0.4822835	test: 0.9794061	best: 0.9794061 (3000)	total: 2m 21s	remaining: 1h 16m 16s
# 3100:	learn: 0.4717091	test: 0.9790140	best: 0.9790051 (3084)	total: 2m 26s	remaining: 1h 16m 17s
# 3200:	learn: 0.4612899	test: 0.9785998	best: 0.9785738 (3196)	total: 2m 31s	remaining: 1h 16m 15s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.978573768
# bestIteration = 3196
#
# Shrink model to first 3197 iterations.
# Fold 2 RMSE: 0.9786
# 0:	learn: 1.7416827	test: 1.7676891	best: 1.7676891 (0)	total: 46.5ms	remaining: 1h 17m 33s
# 100:	learn: 1.0949265	test: 1.1314795	best: 1.1314795 (100)	total: 4.7s	remaining: 1h 17m 28s
# 200:	learn: 1.0335259	test: 1.0891488	best: 1.0891488 (200)	total: 9.59s	remaining: 1h 19m 21s
# 300:	learn: 0.9914871	test: 1.0685734	best: 1.0685734 (300)	total: 14.3s	remaining: 1h 18m 56s
# 400:	learn: 0.9485518	test: 1.0538546	best: 1.0538546 (400)	total: 18.9s	remaining: 1h 18m 20s
# 500:	learn: 0.9091265	test: 1.0429861	best: 1.0429611 (499)	total: 23.6s	remaining: 1h 18m 12s
# 600:	learn: 0.8755353	test: 1.0358528	best: 1.0358528 (600)	total: 28.2s	remaining: 1h 17m 52s
# 700:	learn: 0.8458996	test: 1.0297761	best: 1.0297761 (700)	total: 32.9s	remaining: 1h 17m 45s
# 800:	learn: 0.8190303	test: 1.0251942	best: 1.0251942 (800)	total: 37.9s	remaining: 1h 18m 12s
# 900:	learn: 0.7952201	test: 1.0207599	best: 1.0207599 (900)	total: 43.1s	remaining: 1h 19m 3s
# 1000:	learn: 0.7716985	test: 1.0187432	best: 1.0186023 (998)	total: 48.2s	remaining: 1h 19m 23s
# 1100:	learn: 0.7504026	test: 1.0168016	best: 1.0167295 (1095)	total: 53.1s	remaining: 1h 19m 29s
# 1200:	learn: 0.7294530	test: 1.0140847	best: 1.0140847 (1200)	total: 57.9s	remaining: 1h 19m 20s
# 1300:	learn: 0.7099876	test: 1.0120474	best: 1.0120474 (1300)	total: 1m 2s	remaining: 1h 19m 22s
# 1400:	learn: 0.6911543	test: 1.0104978	best: 1.0104733 (1382)	total: 1m 7s	remaining: 1h 19m 15s
# 1500:	learn: 0.6739110	test: 1.0094667	best: 1.0094577 (1498)	total: 1m 12s	remaining: 1h 18m 59s
# 1600:	learn: 0.6567381	test: 1.0083239	best: 1.0082833 (1589)	total: 1m 17s	remaining: 1h 19m 22s
# 1700:	learn: 0.6408461	test: 1.0071225	best: 1.0070354 (1693)	total: 1m 22s	remaining: 1h 19m 28s
# 1800:	learn: 0.6253784	test: 1.0066348	best: 1.0063994 (1782)	total: 1m 27s	remaining: 1h 19m 27s
# 1900:	learn: 0.6108602	test: 1.0058809	best: 1.0058695 (1896)	total: 1m 32s	remaining: 1h 19m 46s
# 2000:	learn: 0.5959536	test: 1.0055205	best: 1.0054966 (1998)	total: 1m 37s	remaining: 1h 19m 47s
# 2100:	learn: 0.5818973	test: 1.0047304	best: 1.0045397 (2087)	total: 1m 42s	remaining: 1h 19m 23s
# 2200:	learn: 0.5685472	test: 1.0038959	best: 1.0038959 (2200)	total: 1m 47s	remaining: 1h 19m 19s
# 2300:	learn: 0.5555990	test: 1.0038280	best: 1.0037327 (2217)	total: 1m 52s	remaining: 1h 19m 16s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.003732717
# bestIteration = 2217
#
# Shrink model to first 2218 iterations.
# Fold 3 RMSE: 1.0037
# 0:	learn: 1.7396291	test: 1.7777723	best: 1.7777723 (0)	total: 44.6ms	remaining: 1h 14m 17s
# 100:	learn: 1.0956036	test: 1.1293193	best: 1.1293193 (100)	total: 4.54s	remaining: 1h 14m 55s
# 200:	learn: 1.0337298	test: 1.0853901	best: 1.0853901 (200)	total: 9.05s	remaining: 1h 14m 53s
# 300:	learn: 0.9919293	test: 1.0664129	best: 1.0664129 (300)	total: 14.2s	remaining: 1h 18m 11s
# 400:	learn: 0.9491177	test: 1.0531087	best: 1.0531087 (400)	total: 18.8s	remaining: 1h 17m 55s
# 500:	learn: 0.9101954	test: 1.0443964	best: 1.0443964 (500)	total: 23.4s	remaining: 1h 17m 28s
# 600:	learn: 0.8765412	test: 1.0381715	best: 1.0381254 (596)	total: 28s	remaining: 1h 17m 15s
# 700:	learn: 0.8451169	test: 1.0326041	best: 1.0325973 (698)	total: 32.5s	remaining: 1h 16m 44s
# 800:	learn: 0.8177233	test: 1.0281993	best: 1.0281993 (800)	total: 36.9s	remaining: 1h 16m 13s
# 900:	learn: 0.7922452	test: 1.0249100	best: 1.0249100 (900)	total: 41.4s	remaining: 1h 15m 50s
# 1000:	learn: 0.7683766	test: 1.0224646	best: 1.0224646 (1000)	total: 45.8s	remaining: 1h 15m 28s
# 1100:	learn: 0.7447519	test: 1.0193667	best: 1.0193524 (1099)	total: 50.2s	remaining: 1h 15m 12s
# 1200:	learn: 0.7250316	test: 1.0173309	best: 1.0173020 (1197)	total: 54.7s	remaining: 1h 14m 59s
# 1300:	learn: 0.7049250	test: 1.0157649	best: 1.0157649 (1300)	total: 59.2s	remaining: 1h 14m 49s
# 1400:	learn: 0.6862190	test: 1.0143315	best: 1.0143315 (1400)	total: 1m 3s	remaining: 1h 14m 41s
# 1500:	learn: 0.6683169	test: 1.0130178	best: 1.0130178 (1500)	total: 1m 8s	remaining: 1h 14m 31s
# 1600:	learn: 0.6511227	test: 1.0118218	best: 1.0117982 (1598)	total: 1m 12s	remaining: 1h 14m 23s
# 1700:	learn: 0.6350889	test: 1.0106553	best: 1.0106350 (1696)	total: 1m 17s	remaining: 1h 14m 13s
# 1800:	learn: 0.6185961	test: 1.0095434	best: 1.0095025 (1796)	total: 1m 21s	remaining: 1h 14m 7s
# 1900:	learn: 0.6034553	test: 1.0083341	best: 1.0081497 (1888)	total: 1m 26s	remaining: 1h 14m
# 2000:	learn: 0.5895449	test: 1.0075479	best: 1.0075479 (2000)	total: 1m 30s	remaining: 1h 13m 59s
# 2100:	learn: 0.5760605	test: 1.0068173	best: 1.0068019 (2099)	total: 1m 35s	remaining: 1h 14m 13s
# 2200:	learn: 0.5623997	test: 1.0062158	best: 1.0062106 (2186)	total: 1m 40s	remaining: 1h 14m 22s
# 2300:	learn: 0.5498042	test: 1.0062218	best: 1.0061747 (2270)	total: 1m 45s	remaining: 1h 14m 24s
# 2400:	learn: 0.5376002	test: 1.0057790	best: 1.0057158 (2389)	total: 1m 49s	remaining: 1h 14m 24s
# 2500:	learn: 0.5261241	test: 1.0052821	best: 1.0052821 (2500)	total: 1m 54s	remaining: 1h 14m 20s
# 2600:	learn: 0.5144195	test: 1.0045383	best: 1.0044880 (2598)	total: 1m 59s	remaining: 1h 14m 20s
# 2700:	learn: 0.5030544	test: 1.0042697	best: 1.0042151 (2691)	total: 2m 3s	remaining: 1h 14m 19s
# 2800:	learn: 0.4923112	test: 1.0040097	best: 1.0040097 (2800)	total: 2m 8s	remaining: 1h 14m 11s
# 2900:	learn: 0.4820906	test: 1.0038052	best: 1.0037977 (2899)	total: 2m 12s	remaining: 1h 14m 5s
# 3000:	learn: 0.4714150	test: 1.0033054	best: 1.0032254 (2989)	total: 2m 17s	remaining: 1h 13m 55s
# 3100:	learn: 0.4610892	test: 1.0029710	best: 1.0029710 (3100)	total: 2m 21s	remaining: 1h 13m 48s
# 3200:	learn: 0.4514292	test: 1.0029435	best: 1.0027021 (3158)	total: 2m 26s	remaining: 1h 13m 43s
# 3300:	learn: 0.4415118	test: 1.0024004	best: 1.0024004 (3300)	total: 2m 30s	remaining: 1h 13m 37s
# 3400:	learn: 0.4320910	test: 1.0021500	best: 1.0021474 (3399)	total: 2m 35s	remaining: 1h 13m 29s
# 3500:	learn: 0.4232850	test: 1.0016215	best: 1.0016215 (3500)	total: 2m 39s	remaining: 1h 13m 24s
# 3600:	learn: 0.4149598	test: 1.0014145	best: 1.0013884 (3598)	total: 2m 44s	remaining: 1h 13m 18s
# 3700:	learn: 0.4067452	test: 1.0012725	best: 1.0011383 (3645)	total: 2m 48s	remaining: 1h 13m 13s
# 3800:	learn: 0.3985495	test: 1.0012961	best: 1.0010427 (3754)	total: 2m 53s	remaining: 1h 13m 6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.001042686
# bestIteration = 3754
#
# Shrink model to first 3755 iterations.
# Fold 4 RMSE: 1.0010
# FINISHED \ whole score: 0.9939
# 0.9939289821226506
# score:0.9939289821226506

# %%
cv = np.sqrt(mean_squared_error(train_y, oof_cat))
print(f'score:{cv}')
sub['likes'] = np.expm1(prediction_cat)
sub['likes'] = sub['likes'].map(lambda x: x if x > 0 else 0)
sub.to_csv(f'../outputs/cv{cv}.csv', index=False)
# Out:
# score:0.9939289821226506

# %% [markdown]
# # ensemble

# %%
oof_en = (oof_lgbm + oof_xgb + oof_cat) / 3 
prediction_en = (prediction_lgbm + prediction_xgb + prediction_cat) / 3 

cv = np.sqrt(mean_squared_error(train_y, oof_en))
print(f'score:{cv}')
sub['likes'] = np.expm1(prediction_en)
sub['likes'] = sub['likes'].map(lambda x: x if x > 0 else 0)
sub.to_csv(f'../outputs/cv{cv}.csv', index=False)
# Out:
# score:0.9871630728530295
